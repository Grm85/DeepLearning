# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Garima Choudhary
#
# Vem du har presenterat för: Individual
#
# Datum då du presenterade: 8 May 2024
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
from PIL import Image
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %%
model = ResNet50(weights='imagenet')

# %%
# img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
img_path = 'tennisboll.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted: [('n04409515', 'tennis_ball', 0.9999969), ('n04039381', 'racket', 2.7498354e-06), ('n03942813', 'ping-pong_ball', 5.5182866e-08)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %% [markdown]
# ## prediction 1

# %%
# Load the pre-trained ResNet50 model with ImageNet weights
model = ResNet50(weights='imagenet')

# %%
img_path = 'gazelle.jpg'

# %%
# Load and preprocess my personal image
img_path = 'C:/Users/LENOVO/OneDrive/Desktop/imagescnn/gazelle.jpg'
img_path = 'gazelle.jpg'
img = image.load_img('C:/Users/LENOVO/OneDrive/Desktop/imagescnn/gazelle.jpg', target_size=(224, 224))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 1, 224, 224, 3)

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
import numpy as np

# Assuming x is input data
# Add an extra dimension to represent the batch size
x = np.expand_dims(x, axis=0)

# Now, the shape of x should be (1, 224, 224, 3)
# now passing reshaped input data to the model for prediction
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 126ms/step
# Predicted: [('n02423022', 'gazelle', 0.5029748), ('n02422699', 'impala', 0.32196465), ('n02422106', 'hartebeest', 0.08160144)]

# %% [markdown]
# ##  Prediction 2

# %%
# Load the pre-trained CNN model
model = ResNet50(weights='imagenet')

# %%
img_path = 'trailer_truck.jpg'

# %%
# Load and preprocess my personal image
img_path = "C:/Users/LENOVO/OneDrive/Desktop/imagescnn/trailer_truck.jpg"
img_path = 'trailer_truck.jpg'
img = image.load_img("C:/Users/LENOVO/OneDrive/Desktop/imagescnn/trailer_truck.jpg", target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 1, 224, 224, 3)

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
import numpy as np

# Assuming x is my input data
# Add an extra dimension to represent the batch size
x = np.expand_dims(x, axis=0)

# Now, the shape of x should be (1, 224, 224, 3)
# passing this reshaped input data to the model for prediction
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 134ms/step
# Predicted: [('n04467665', 'trailer_truck', 0.9784239), ('n04461696', 'tow_truck', 0.008860304), ('n03796401', 'moving_van', 0.005605567)]

# %% [markdown]
# ## Prediction 3

# %%
# Load the pre-trained CNN model
model = ResNet50(weights='imagenet')

# %%
img_path = 'pizza.jpg'

# %%
# Load and preprocess my personal image
img_path = "C:/Users/LENOVO/OneDrive/Desktop/imagescnn/pizza.JPG"
img_path = 'pizza.jpg'
img = image.load_img("C:/Users/LENOVO/OneDrive/Desktop/imagescnn/pizza.JPG", target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 1, 224, 224, 3)

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
import numpy as np

# Assuming x is my input data
# Add an extra dimension to represent the batch size
x = np.expand_dims(x, axis=0)

# Now, the shape of x should be (1, 224, 224, 3)
# passing this reshaped input data to the model for prediction
preds = model.predict(x)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 119ms/step
# Predicted: [('n07873807', 'pizza', 0.9999269), ('n07875152', 'potpie', 6.268144e-05), ('n07684084', 'French_loaf', 2.7129759e-06)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %% [markdown]
# Pretained models are powerful concepts as they are trained on large datasets to accomplish specific tasks and can be used as they are or customized to suit application requirements across multiple industries. The databases on which these models are trained are usually very large and diverse, comprising a wide range of patterns and features. As a result, they can provide a strong foundation for fine-tuning and can significantly improve the performance of the model. Hence, they save time, money, and effort
